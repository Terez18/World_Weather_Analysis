# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# unzip the tuple (can do it once only)
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
#import requests library 
import requests

# Import the weather API key.
from config import weather_api_key

# %%
# Build the basic URL for the OpenWeatherMap with your weather_api_key added to the URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list. 
#This is not a good option for retrieving the cities because it pulls the index of the city and will cause errors. in order to get the city name we need to create another for loop. instead of creating a second for loop we can use the code with enumerate such as in the next box.  
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
    
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Weather": city_weather_description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 15 | port blair
# Processing Record 2 of Set 15 | kamiichi
# Processing Record 3 of Set 15 | pisco
# Processing Record 4 of Set 15 | rikitea
# Processing Record 5 of Set 15 | asau
# Processing Record 6 of Set 15 | sechura
# Processing Record 7 of Set 15 | tromso
# Processing Record 8 of Set 15 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 15 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 15 | bluff
# Processing Record 11 of Set 15 | vestmannaeyjar
# Processing Record 12 of Set 15 | great falls
# Processing Record 13 of Set 15 | haines junction
# Processing Record 14 of Set 15 | tiksi
# Processing Record 15 of Set 15 | mehamn
# Processing Record 16 of Set 15 | iskateley
# Processing Record 17 of Set 15 | dothan
# Processing Record 18 of Set 15 | nuevo progreso
# Processing Record 19 of Set 15 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 15 | severo-kurilsk
# Processing Record 21 of Set 15 | saint-philippe
# Processing Record 22 of Set 15 | valparaiso
# Processing Record 23 of Set 15 | banjar
# Processing Record 24 of Set 15 | norman wells
# Processing Record 25 of Set 15 | busselton
# Processing Record 26 of Set 15 | ivanteyevka
# Processing Record 27 of Set 15 | yellowknife
# Processing Record 28 of Set 15 | tabialan
# City not found. Skipping...
# Processing Record 29 of Set 15 | aksu
# Processing Record 30 of Set 15 | vaini
# Processing Record 31 of Set 15 | komsomolskiy
# Processing Record 32 of Set 15 | longyearbyen
# Processing Record 33 of Set 15 | mahebourg
# Processing Record 34 of Set 15 | svetlaya
# Processing Record 35 of Set 15 | cape town
# Processing Record 36 of Set 15 | ahipara
# Processing Record 37 of Set 15 | aswan
# Processing Record 38 of Set 15 | maningrida
# Processing Record 39 of Set 15 | puerto ayora
# Processing Record 40 of Set 15 | hermanus
# Processing Record 41 of Set 15 | kahului
# Processing Record 42 of Set 15 | cockburn town
# Processing Record 43 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 44 of Set 15 | albany
# Processing Record 45 of Set 15 | provideniya
# Processing Record 46 of Set 15 | tura
# Processing Record 47 of Set 15 | saint anthony
# Processing Record 48 of Set 15 | murgab
# Processing Record 49 of Set 15 | namibe
# Processing Record 50 of Set 15 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 16 | punta arenas
# Processing Record 2 of Set 16 | castro
# Processing Record 3 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 16 | saskylakh
# Processing Record 5 of Set 16 | nikolskoye
# Processing Record 6 of Set 16 | nguiu
# City not found. Skipping...
# Processing Record 7 of Set 16 | carlagan
# Processing Record 8 of Set 16 | chokurdakh
# Processing Record 9 of Set 16 | pevek
# Processing Record 10 of Set 16 | pangnirtung
# Processing Record 11 of Set 16 | dikson
# Processing Record 12 of Set 16 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 16 | alta floresta
# Processing Record 14 of Set 16 | broome
# Processing Record 15 of Set 16 | northam
# Processing Record 16 of Set 16 | hilo
# Processing Record 17 of Set 16 | victoria
# Processing Record 18 of Set 16 | shingu
# Processing Record 19 of Set 16 | avarua
# Processing Record 20 of Set 16 | maniwaki
# Processing Record 21 of Set 16 | aklavik
# Processing Record 22 of Set 16 | mataura
# Processing Record 23 of Set 16 | saint george
# Processing Record 24 of Set 16 | hurghada
# Processing Record 25 of Set 16 | santa cruz
# Processing Record 26 of Set 16 | port alfred
# Processing Record 27 of Set 16 | khatanga
# Processing Record 28 of Set 16 | hearst
# Processing Record 29 of Set 16 | sitka
# Processing Record 30 of Set 16 | agadez
# Processing Record 31 of Set 16 | bocas del toro
# Processing Record 32 of Set 16 | sao filipe
# Processing Record 33 of Set 16 | faanui
# Processing Record 34 of Set 16 | ushuaia
# Processing Record 35 of Set 16 | new norfolk
# Processing Record 36 of Set 16 | pochutla
# Processing Record 37 of Set 16 | payson
# Processing Record 38 of Set 16 | port hardy
# Processing Record 39 of Set 16 | qasigiannguit
# Processing Record 40 of Set 16 | cayenne
# Processing Record 41 of Set 16 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 16 | axim
# Processing Record 43 of Set 16 | barrow
# Processing Record 44 of Set 16 | kodiak
# Processing Record 45 of Set 16 | almaznyy
# Processing Record 46 of Set 16 | pasarkemis
# Processing Record 47 of Set 16 | tuktoyaktuk
# Processing Record 48 of Set 16 | lebu
# Processing Record 49 of Set 16 | kapaa
# Processing Record 50 of Set 16 | kirakira
# Processing Record 1 of Set 17 | anadyr
# Processing Record 2 of Set 17 | vaitape
# Processing Record 3 of Set 17 | prince rupert
# Processing Record 4 of Set 17 | isangel
# Processing Record 5 of Set 17 | ust-nera
# Processing Record 6 of Set 17 | luang prabang
# Processing Record 7 of Set 17 | milford
# Processing Record 8 of Set 17 | bengkulu
# Processing Record 9 of Set 17 | mareeba
# Processing Record 10 of Set 17 | cidreira
# Processing Record 11 of Set 17 | jamestown
# Processing Record 12 of Set 17 | bredasdorp
# Processing Record 13 of Set 17 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 17 | along
# Processing Record 15 of Set 17 | atuona
# Processing Record 16 of Set 17 | butaritari
# Processing Record 17 of Set 17 | great bend
# Processing Record 18 of Set 17 | avera
# Processing Record 19 of Set 17 | manavalakurichi
# Processing Record 20 of Set 17 | ahuimanu
# Processing Record 21 of Set 17 | kholtoson
# Processing Record 22 of Set 17 | umm durman
# City not found. Skipping...
# Processing Record 23 of Set 17 | mezen
# Processing Record 24 of Set 17 | mogadishu
# Processing Record 25 of Set 17 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 17 | half moon bay
# Processing Record 27 of Set 17 | constitucion
# Processing Record 28 of Set 17 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 17 | pingliang
# Processing Record 30 of Set 17 | nizhniy kuranakh
# Processing Record 31 of Set 17 | olinda
# Processing Record 32 of Set 17 | sapa
# Processing Record 33 of Set 17 | arraial do cabo
# Processing Record 34 of Set 17 | lorengau
# Processing Record 35 of Set 17 | chuy
# Processing Record 36 of Set 17 | viedma
# Processing Record 37 of Set 17 | japura
# Processing Record 38 of Set 17 | nazarovo
# Processing Record 39 of Set 17 | bethel
# Processing Record 40 of Set 17 | tasiilaq
# Processing Record 41 of Set 17 | ludwigslust
# Processing Record 42 of Set 17 | inta
# Processing Record 43 of Set 17 | praia da vitoria
# Processing Record 44 of Set 17 | egvekinot
# Processing Record 45 of Set 17 | ayan
# Processing Record 46 of Set 17 | cherskiy
# Processing Record 47 of Set 17 | rhyl
# Processing Record 48 of Set 17 | kjollefjord
# Processing Record 49 of Set 17 | puerto del rosario
# Processing Record 50 of Set 17 | katsuura
# Processing Record 1 of Set 18 | hobart
# Processing Record 2 of Set 18 | guiratinga
# Processing Record 3 of Set 18 | lewisporte
# Processing Record 4 of Set 18 | kaitangata
# Processing Record 5 of Set 18 | saldanha
# Processing Record 6 of Set 18 | saint-georges
# Processing Record 7 of Set 18 | altay
# Processing Record 8 of Set 18 | swellendam
# Processing Record 9 of Set 18 | gorontalo
# Processing Record 10 of Set 18 | karaul
# City not found. Skipping...
# Processing Record 11 of Set 18 | vila
# Processing Record 12 of Set 18 | bang saphan
# Processing Record 13 of Set 18 | north bend
# Processing Record 14 of Set 18 | atambua
# Processing Record 15 of Set 18 | belaya gora
# Processing Record 16 of Set 18 | san ramon
# Processing Record 17 of Set 18 | ambon
# Processing Record 18 of Set 18 | cepu
# Processing Record 19 of Set 18 | luderitz
# Processing Record 20 of Set 18 | safaqis
# City not found. Skipping...
# Processing Record 21 of Set 18 | suntar
# Processing Record 22 of Set 18 | folkestone
# Processing Record 23 of Set 18 | labutta
# City not found. Skipping...
# Processing Record 24 of Set 18 | mar del plata
# Processing Record 25 of Set 18 | urubicha
# Processing Record 26 of Set 18 | naugarzan
# City not found. Skipping...
# Processing Record 27 of Set 18 | urucara
# Processing Record 28 of Set 18 | mbandaka
# Processing Record 29 of Set 18 | tando muhammad khan
# Processing Record 30 of Set 18 | lamu
# Processing Record 31 of Set 18 | newport
# Processing Record 32 of Set 18 | camacha
# Processing Record 33 of Set 18 | ust-maya
# Processing Record 34 of Set 18 | lensk
# Processing Record 35 of Set 18 | liverpool
# Processing Record 36 of Set 18 | dudinka
# Processing Record 37 of Set 18 | codrington
# Processing Record 38 of Set 18 | leningradskiy
# Processing Record 39 of Set 18 | kavieng
# Processing Record 40 of Set 18 | inhambane
# Processing Record 41 of Set 18 | qaanaaq
# Processing Record 42 of Set 18 | cape coast
# Processing Record 43 of Set 18 | awjilah
# Processing Record 44 of Set 18 | hay river
# Processing Record 45 of Set 18 | alofi
# Processing Record 46 of Set 18 | necochea
# Processing Record 47 of Set 18 | nanortalik
# Processing Record 48 of Set 18 | lavrentiya
# Processing Record 49 of Set 18 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 18 | camalu
# Processing Record 1 of Set 19 | marrakesh
# Processing Record 2 of Set 19 | itacoatiara
# Processing Record 3 of Set 19 | kamennomostskiy
# Processing Record 4 of Set 19 | deer lake
# Processing Record 5 of Set 19 | saint-joseph
# Processing Record 6 of Set 19 | durusu
# Processing Record 7 of Set 19 | naze
# Processing Record 8 of Set 19 | beringovskiy
# Processing Record 9 of Set 19 | port macquarie
# Processing Record 10 of Set 19 | chapais
# Processing Record 11 of Set 19 | bathsheba
# Processing Record 12 of Set 19 | okha
# Processing Record 13 of Set 19 | shubarkuduk
# Processing Record 14 of Set 19 | coquimbo
# Processing Record 15 of Set 19 | nosy varika
# Processing Record 16 of Set 19 | yulara
# Processing Record 17 of Set 19 | namtsy
# Processing Record 18 of Set 19 | airai
# Processing Record 19 of Set 19 | makakilo city
# Processing Record 20 of Set 19 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 19 | ribeira grande
# Processing Record 22 of Set 19 | ancud
# Processing Record 23 of Set 19 | carnarvon
# Processing Record 24 of Set 19 | vila franca do campo
# Processing Record 25 of Set 19 | mackenzie
# Processing Record 26 of Set 19 | jaque
# Processing Record 27 of Set 19 | tailai
# Processing Record 28 of Set 19 | torbay
# Processing Record 29 of Set 19 | iqaluit
# Processing Record 30 of Set 19 | ca mau
# Processing Record 31 of Set 19 | mentok
# City not found. Skipping...
# Processing Record 32 of Set 19 | neuquen
# Processing Record 33 of Set 19 | nome
# Processing Record 34 of Set 19 | qarqin
# Processing Record 35 of Set 19 | fortuna
# Processing Record 36 of Set 19 | orbetello
# Processing Record 37 of Set 19 | saint-pierre
# Processing Record 38 of Set 19 | saraland
# Processing Record 39 of Set 19 | bilibino
# Processing Record 40 of Set 19 | touros
# Processing Record 41 of Set 19 | thompson
# Processing Record 42 of Set 19 | uncia
# Processing Record 43 of Set 19 | sibenik
# Processing Record 44 of Set 19 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 19 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 19 | ust-shonosha
# Processing Record 47 of Set 19 | luganville
# Processing Record 48 of Set 19 | dongsheng
# Processing Record 49 of Set 19 | sorland
# Processing Record 50 of Set 19 | port-gentil
# Processing Record 1 of Set 20 | santa fe
# Processing Record 2 of Set 20 | sungaipenuh
# Processing Record 3 of Set 20 | kieta
# Processing Record 4 of Set 20 | vardo
# Processing Record 5 of Set 20 | omboue
# Processing Record 6 of Set 20 | khairpur nathan shah
# Processing Record 7 of Set 20 | booue
# Processing Record 8 of Set 20 | porterville
# Processing Record 9 of Set 20 | rio grande
# Processing Record 10 of Set 20 | goderich
# Processing Record 11 of Set 20 | cabedelo
# Processing Record 12 of Set 20 | zelenoborskiy
# Processing Record 13 of Set 20 | dingle
# Processing Record 14 of Set 20 | namatanai
# Processing Record 15 of Set 20 | sharanga
# Processing Record 16 of Set 20 | tiarei
# Processing Record 17 of Set 20 | hakui
# Processing Record 18 of Set 20 | hithadhoo
# Processing Record 19 of Set 20 | palmas
# Processing Record 20 of Set 20 | hofn
# Processing Record 21 of Set 20 | okhotsk
# Processing Record 22 of Set 20 | muros
# Processing Record 23 of Set 20 | nishihara
# Processing Record 24 of Set 20 | tilichiki
# Processing Record 25 of Set 20 | te anau
# Processing Record 26 of Set 20 | san cristobal
# Processing Record 27 of Set 20 | am timan
# Processing Record 28 of Set 20 | south lake tahoe
# Processing Record 29 of Set 20 | salalah
# Processing Record 30 of Set 20 | zabol
# Processing Record 31 of Set 20 | mullaitivu
# City not found. Skipping...
# Processing Record 32 of Set 20 | soyo
# Processing Record 33 of Set 20 | vikhorevka
# Processing Record 34 of Set 20 | kruisfontein
# Processing Record 35 of Set 20 | vao
# Processing Record 36 of Set 20 | ewa beach
# Processing Record 37 of Set 20 | lethem
# Processing Record 38 of Set 20 | zhezkazgan
# Processing Record 39 of Set 20 | orodara
# Processing Record 40 of Set 20 | port elizabeth
# Processing Record 41 of Set 20 | dondo
# Processing Record 42 of Set 20 | saint-louis
# Processing Record 43 of Set 20 | abdanan
# Processing Record 44 of Set 20 | morro bay
# Processing Record 45 of Set 20 | nemuro
# Processing Record 46 of Set 20 | yairipok
# Processing Record 47 of Set 20 | ambodifototra
# City not found. Skipping...
# Processing Record 48 of Set 20 | lata
# Processing Record 49 of Set 20 | sobolevo
# Processing Record 50 of Set 20 | kaniama
# Processing Record 1 of Set 21 | carutapera
# Processing Record 2 of Set 21 | visby
# Processing Record 3 of Set 21 | kencong
# Processing Record 4 of Set 21 | san andres
# Processing Record 5 of Set 21 | emerald
# Processing Record 6 of Set 21 | yar-sale
# Processing Record 7 of Set 21 | mount gambier
# Processing Record 8 of Set 21 | savonlinna
# Processing Record 9 of Set 21 | port hedland
# Processing Record 10 of Set 21 | chimore
# Processing Record 11 of Set 21 | bure
# Processing Record 12 of Set 21 | yanam
# Processing Record 13 of Set 21 | huarmey
# Processing Record 14 of Set 21 | imbituba
# Processing Record 15 of Set 21 | east london
# Processing Record 16 of Set 21 | los llanos de aridane
# Processing Record 17 of Set 21 | antigonish
# Processing Record 18 of Set 21 | ola
# Processing Record 19 of Set 21 | illintsi
# Processing Record 20 of Set 21 | tukrah
# Processing Record 21 of Set 21 | ilheus
# Processing Record 22 of Set 21 | san diego de la union
# Processing Record 23 of Set 21 | acarau
# Processing Record 24 of Set 21 | bolshoye nagatkino
# Processing Record 25 of Set 21 | ocos
# Processing Record 26 of Set 21 | adrar
# Processing Record 27 of Set 21 | porto novo
# Processing Record 28 of Set 21 | ponta do sol
# Processing Record 29 of Set 21 | beni
# Processing Record 30 of Set 21 | poum
# Processing Record 31 of Set 21 | cheremukhovo
# Processing Record 32 of Set 21 | rawah
# Processing Record 33 of Set 21 | matara
# Processing Record 34 of Set 21 | lasa
# Processing Record 35 of Set 21 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 21 | halifax
# Processing Record 37 of Set 21 | tiruttani
# Processing Record 38 of Set 21 | mazamari
# Processing Record 39 of Set 21 | batemans bay
# Processing Record 40 of Set 21 | santa luzia
# Processing Record 41 of Set 21 | mirnyy
# Processing Record 42 of Set 21 | flinders
# Processing Record 43 of Set 21 | caravelas
# Processing Record 44 of Set 21 | tukan
# Processing Record 45 of Set 21 | poselki
# Processing Record 46 of Set 21 | charters towers
# Processing Record 47 of Set 21 | geraldton
# Processing Record 48 of Set 21 | klaksvik
# Processing Record 49 of Set 21 | gharb
# City not found. Skipping...
# Processing Record 50 of Set 21 | manono
# Processing Record 1 of Set 22 | annau
# Processing Record 2 of Set 22 | awbari
# Processing Record 3 of Set 22 | nenjiang
# Processing Record 4 of Set 22 | clyde river
# Processing Record 5 of Set 22 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 22 | yumen
# Processing Record 7 of Set 22 | cherkasskoye
# Processing Record 8 of Set 22 | kontagora
# Processing Record 9 of Set 22 | lazaro cardenas
# Processing Record 10 of Set 22 | jabinyanah
# Processing Record 11 of Set 22 | kununurra
# Processing Record 12 of Set 22 | georgetown
# Processing Record 13 of Set 22 | lima
# Processing Record 14 of Set 22 | fairbanks
# Processing Record 15 of Set 22 | kahama
# Processing Record 16 of Set 22 | manzanillo
# Processing Record 17 of Set 22 | ninh binh
# Processing Record 18 of Set 22 | talnakh
# Processing Record 19 of Set 22 | prado
# Processing Record 20 of Set 22 | yarada
# Processing Record 21 of Set 22 | huntington
# Processing Record 22 of Set 22 | beroroha
# Processing Record 23 of Set 22 | mutoko
# Processing Record 24 of Set 22 | penzance
# Processing Record 25 of Set 22 | louisbourg
# City not found. Skipping...
# Processing Record 26 of Set 22 | shahdadkot
# Processing Record 27 of Set 22 | sisimiut
# Processing Record 28 of Set 22 | lagoa
# Processing Record 29 of Set 22 | mao
# Processing Record 30 of Set 22 | payo
# Processing Record 31 of Set 22 | boyolangu
# Processing Record 32 of Set 22 | talcahuano
# Processing Record 33 of Set 22 | kasongo-lunda
# Processing Record 34 of Set 22 | yatou
# Processing Record 35 of Set 22 | upernavik
# Processing Record 36 of Set 22 | gallup
# Processing Record 37 of Set 22 | samarai
# Processing Record 38 of Set 22 | kropotkin
# Processing Record 39 of Set 22 | cabatuan
# Processing Record 40 of Set 22 | balkanabat
# Processing Record 41 of Set 22 | itarema
# Processing Record 42 of Set 22 | tessalit
# Processing Record 43 of Set 22 | atasu
# Processing Record 44 of Set 22 | san pedro
# Processing Record 45 of Set 22 | bichena
# Processing Record 46 of Set 22 | terrace
# Processing Record 47 of Set 22 | san angelo
# Processing Record 48 of Set 22 | komsomolets
# Processing Record 49 of Set 22 | husavik
# Processing Record 50 of Set 22 | soloneshnoye
# Processing Record 1 of Set 23 | cabo san lucas
# Processing Record 2 of Set 23 | nador
# Processing Record 3 of Set 23 | vanimo
# Processing Record 4 of Set 23 | strathroy
# Processing Record 5 of Set 23 | kapiri mposhi
# Processing Record 6 of Set 23 | smirnykh
# Processing Record 7 of Set 23 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 23 | hasaki
# Processing Record 9 of Set 23 | luba
# Processing Record 10 of Set 23 | vilyuysk
# Processing Record 11 of Set 23 | timmins
# Processing Record 12 of Set 23 | santa cruz de tenerife
# Processing Record 13 of Set 23 | mandalgovi
# Processing Record 14 of Set 23 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 23 | sistranda
# Processing Record 16 of Set 23 | myitkyina
# Processing Record 17 of Set 23 | shelburne
# Processing Record 18 of Set 23 | ketchikan
# Processing Record 19 of Set 23 | laguna
# Processing Record 20 of Set 23 | nagato
# Processing Record 21 of Set 23 | ambilobe
# Processing Record 22 of Set 23 | alyangula
# Processing Record 23 of Set 23 | qui nhon
# Processing Record 24 of Set 23 | juneau
# Processing Record 25 of Set 23 | solnechnyy
# Processing Record 26 of Set 23 | esperance
# Processing Record 27 of Set 23 | boca do acre
# Processing Record 28 of Set 23 | pareora
# Processing Record 29 of Set 23 | manzhouli
# Processing Record 30 of Set 23 | hirado
# Processing Record 31 of Set 23 | belmonte
# Processing Record 32 of Set 23 | gua musang
# Processing Record 33 of Set 23 | carballo
# Processing Record 34 of Set 23 | manokwari
# Processing Record 35 of Set 23 | tsienyane
# City not found. Skipping...
# Processing Record 36 of Set 23 | korla
# Processing Record 37 of Set 23 | saint-augustin
# Processing Record 38 of Set 23 | sangamner
# Processing Record 39 of Set 23 | ucluelet
# Processing Record 40 of Set 23 | jiwani
# Processing Record 41 of Set 23 | dera bugti
# Processing Record 42 of Set 23 | bandarbeyla
# Processing Record 43 of Set 23 | eyl
# Processing Record 44 of Set 23 | srednekolymsk
# Processing Record 45 of Set 23 | hobyo
# Processing Record 46 of Set 23 | nevers
# Processing Record 47 of Set 23 | nanga eboko
# Processing Record 48 of Set 23 | rakovski
# Processing Record 49 of Set 23 | kudahuvadhoo
# Processing Record 50 of Set 23 | itoman
# Processing Record 1 of Set 24 | narva
# Processing Record 2 of Set 24 | sioux lookout
# Processing Record 3 of Set 24 | salamiyah
# Processing Record 4 of Set 24 | karamay
# City not found. Skipping...
# Processing Record 5 of Set 24 | marawi
# Processing Record 6 of Set 24 | mitu
# Processing Record 7 of Set 24 | luanda
# Processing Record 8 of Set 24 | tanhacu
# Processing Record 9 of Set 24 | pangai
# Processing Record 10 of Set 24 | teyateyaneng
# Processing Record 11 of Set 24 | lockhart
# Processing Record 12 of Set 24 | sur
# Processing Record 13 of Set 24 | olafsvik
# Processing Record 14 of Set 24 | itapirapua
# Processing Record 15 of Set 24 | mankono
# Processing Record 16 of Set 24 | irtyshskiy
# Processing Record 17 of Set 24 | lusambo
# Processing Record 18 of Set 24 | pangody
# Processing Record 19 of Set 24 | jiddah
# City not found. Skipping...
# Processing Record 20 of Set 24 | bantry
# Processing Record 21 of Set 24 | ostrovnoy
# Processing Record 22 of Set 24 | sept-iles
# Processing Record 23 of Set 24 | pacific grove
# Processing Record 24 of Set 24 | harwich
# Processing Record 25 of Set 24 | quatre cocos
# Processing Record 26 of Set 24 | jogindarnagar
# Processing Record 27 of Set 24 | conselheiro pena
# Processing Record 28 of Set 24 | miramar
# Processing Record 29 of Set 24 | aykhal
# Processing Record 30 of Set 24 | fukuchiyama
# Processing Record 31 of Set 24 | brits
# Processing Record 32 of Set 24 | boende
# Processing Record 33 of Set 24 | nacogdoches
# Processing Record 34 of Set 24 | vanavara
# Processing Record 35 of Set 24 | berdigestyakh
# Processing Record 36 of Set 24 | nouadhibou
# Processing Record 37 of Set 24 | tuy hoa
# Processing Record 38 of Set 24 | grand-santi
# Processing Record 39 of Set 24 | beyneu
# Processing Record 40 of Set 24 | roebourne
# Processing Record 41 of Set 24 | claresholm
# Processing Record 42 of Set 24 | pavlogradka
# Processing Record 43 of Set 24 | pyinmana
# Processing Record 44 of Set 24 | kaeo
# Processing Record 45 of Set 24 | bardiyah
# Processing Record 46 of Set 24 | parrita
# Processing Record 47 of Set 24 | batagay
# Processing Record 48 of Set 24 | hualmay
# Processing Record 49 of Set 24 | angoche
# Processing Record 50 of Set 24 | shimoda
# Processing Record 1 of Set 25 | gzhatsk
# City not found. Skipping...
# Processing Record 2 of Set 25 | dhidhdhoo
# Processing Record 3 of Set 25 | rozhyshche
# Processing Record 4 of Set 25 | sibolga
# Processing Record 5 of Set 25 | taksimo
# Processing Record 6 of Set 25 | kavaratti
# Processing Record 7 of Set 25 | ormara
# Processing Record 8 of Set 25 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 25 | khromtau
# Processing Record 10 of Set 25 | gambela
# Processing Record 11 of Set 25 | oriximina
# Processing Record 12 of Set 25 | kibaya
# Processing Record 13 of Set 25 | nisia floresta
# Processing Record 14 of Set 25 | waddan
# Processing Record 15 of Set 25 | derzhavinsk
# Processing Record 16 of Set 25 | novyy svit
# Processing Record 17 of Set 25 | skagastrond
# City not found. Skipping...
# Processing Record 18 of Set 25 | sochaczew
# Processing Record 19 of Set 25 | hayden
# Processing Record 20 of Set 25 | port lincoln
# Processing Record 21 of Set 25 | tual
# Processing Record 22 of Set 25 | zhangye
# Processing Record 23 of Set 25 | auch
# Processing Record 24 of Set 25 | gizo
# Processing Record 25 of Set 25 | nelidovo
# Processing Record 26 of Set 25 | buraydah
# Processing Record 27 of Set 25 | teya
# Processing Record 28 of Set 25 | hirara
# Processing Record 29 of Set 25 | tonekabon
# Processing Record 30 of Set 25 | lokosovo
# Processing Record 31 of Set 25 | kainantu
# Processing Record 32 of Set 25 | saint-paul
# Processing Record 33 of Set 25 | kiruna
# Processing Record 34 of Set 25 | chicama
# Processing Record 35 of Set 25 | zhigansk
# Processing Record 36 of Set 25 | guerrero negro
# Processing Record 37 of Set 25 | bignona
# Processing Record 38 of Set 25 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 25 | fort nelson
# Processing Record 40 of Set 25 | lompoc
# Processing Record 41 of Set 25 | tarare
# Processing Record 42 of Set 25 | phonhong
# Processing Record 43 of Set 25 | key west
# Processing Record 44 of Set 25 | duz
# City not found. Skipping...
# Processing Record 45 of Set 25 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 25 | khonuu
# City not found. Skipping...
# Processing Record 47 of Set 25 | auki
# Processing Record 48 of Set 25 | itaqui
# Processing Record 49 of Set 25 | felipe carrillo puerto
# Processing Record 50 of Set 25 | san patricio
# Processing Record 1 of Set 26 | kinkala
# Processing Record 2 of Set 26 | chinchinim
# Processing Record 3 of Set 26 | kawana waters
# City not found. Skipping...
# Processing Record 4 of Set 26 | padang
# Processing Record 5 of Set 26 | weiser
# Processing Record 6 of Set 26 | ladario
# Processing Record 7 of Set 26 | benguela
# Processing Record 8 of Set 26 | bitung
# Processing Record 9 of Set 26 | gat
# Processing Record 10 of Set 26 | benghazi
# Processing Record 11 of Set 26 | abu dhabi
# Processing Record 12 of Set 26 | dakar
# Processing Record 13 of Set 26 | krasnoselkup
# Processing Record 14 of Set 26 | bose
# Processing Record 15 of Set 26 | gambiran
# Processing Record 16 of Set 26 | maceio
# Processing Record 17 of Set 26 | nkayi
# Processing Record 18 of Set 26 | milkovo
# Processing Record 19 of Set 26 | brigantine
# Processing Record 20 of Set 26 | ken caryl
# Processing Record 21 of Set 26 | sao joao da barra
# Processing Record 22 of Set 26 | moose factory
# Processing Record 23 of Set 26 | raudeberg
# Processing Record 24 of Set 26 | labuan
# Processing Record 25 of Set 26 | karratha
# Processing Record 26 of Set 26 | pindobacu
# Processing Record 27 of Set 26 | ilulissat
# Processing Record 28 of Set 26 | faya
# Processing Record 29 of Set 26 | placido de castro
# Processing Record 30 of Set 26 | coahuayana
# Processing Record 31 of Set 26 | nuuk
# Processing Record 32 of Set 26 | taboga
# Processing Record 33 of Set 26 | tapes
# Processing Record 34 of Set 26 | tasbuget
# City not found. Skipping...
# Processing Record 35 of Set 26 | canillo
# Processing Record 36 of Set 26 | chimbarongo
# Processing Record 37 of Set 26 | richards bay
# Processing Record 38 of Set 26 | krasnorechenskiy
# Processing Record 39 of Set 26 | matamoros
# Processing Record 40 of Set 26 | carnot
# Processing Record 41 of Set 26 | tazovskiy
# Processing Record 42 of Set 26 | manzil tamim
# City not found. Skipping...
# Processing Record 43 of Set 26 | malakal
# Processing Record 44 of Set 26 | buenos aires
# Processing Record 45 of Set 26 | guajara-mirim
# City not found. Skipping...
# Processing Record 46 of Set 26 | andapa
# Processing Record 47 of Set 26 | port moresby
# Processing Record 48 of Set 26 | tautira
# Processing Record 49 of Set 26 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 26 | margate
# Processing Record 1 of Set 27 | fuyang
# Processing Record 2 of Set 27 | sukumo
# Processing Record 3 of Set 27 | maputo
# Processing Record 4 of Set 27 | svetlogorsk
# Processing Record 5 of Set 27 | mirik
# Processing Record 6 of Set 27 | lyubech
# Processing Record 7 of Set 27 | skibbereen
# Processing Record 8 of Set 27 | tuggurt
# City not found. Skipping...
# Processing Record 9 of Set 27 | a
# City not found. Skipping...
# Processing Record 10 of Set 27 | sieradz
# Processing Record 11 of Set 27 | digby
# Processing Record 12 of Set 27 | pimenta bueno
# Processing Record 13 of Set 27 | masterton
# Processing Record 14 of Set 27 | narsaq
# Processing Record 15 of Set 27 | baturaja
# Processing Record 16 of Set 27 | isakly
# Processing Record 17 of Set 27 | tombouctou
# Processing Record 18 of Set 27 | bambous virieux
# Processing Record 19 of Set 27 | pestovo
# Processing Record 20 of Set 27 | codajas
# Processing Record 21 of Set 27 | slupsk
# Processing Record 22 of Set 27 | xuddur
# Processing Record 23 of Set 27 | mount isa
# Processing Record 24 of Set 27 | moron
# Processing Record 25 of Set 27 | portland
# Processing Record 26 of Set 27 | kamenka
# Processing Record 27 of Set 27 | trinitapoli
# Processing Record 28 of Set 27 | abnub
# Processing Record 29 of Set 27 | noumea
# Processing Record 30 of Set 27 | tuatapere
# Processing Record 31 of Set 27 | muli
# Processing Record 32 of Set 27 | kuala selangor
# Processing Record 33 of Set 27 | rio gallegos
# Processing Record 34 of Set 27 | camocim
# Processing Record 35 of Set 27 | sunndalsora
# Processing Record 36 of Set 27 | dunedin
# Processing Record 37 of Set 27 | rocha
# Processing Record 38 of Set 27 | bababe
# City not found. Skipping...
# Processing Record 39 of Set 27 | college
# Processing Record 40 of Set 27 | vila velha
# Processing Record 41 of Set 27 | beruni
# City not found. Skipping...
# Processing Record 42 of Set 27 | darlawn
# Processing Record 43 of Set 27 | manicore
# Processing Record 44 of Set 27 | gisborne
# Processing Record 45 of Set 27 | toliary
# City not found. Skipping...
# Processing Record 46 of Set 27 | angers
# Processing Record 47 of Set 27 | broken hill
# Processing Record 48 of Set 27 | mocuba
# Processing Record 49 of Set 27 | fort saint john
# City not found. Skipping...
# Processing Record 50 of Set 27 | radzyn podlaski
# Processing Record 1 of Set 28 | porbandar
# Processing Record 2 of Set 28 | billings
# Processing Record 3 of Set 28 | beaupre
# Processing Record 4 of Set 28 | ballangen
# Processing Record 5 of Set 28 | nelson bay
# Processing Record 6 of Set 28 | kitami
# Processing Record 7 of Set 28 | snezhnogorsk
# Processing Record 8 of Set 28 | paamiut
# Processing Record 9 of Set 28 | huilong
# Processing Record 10 of Set 28 | beira
# Processing Record 11 of Set 28 | pankovka
# Processing Record 12 of Set 28 | vigia del fuerte
# Processing Record 13 of Set 28 | yeppoon
# Processing Record 14 of Set 28 | millinocket
# Processing Record 15 of Set 28 | erzin
# Processing Record 16 of Set 28 | leh
# Processing Record 17 of Set 28 | bemidji
# Processing Record 18 of Set 28 | silifke
# Processing Record 19 of Set 28 | truro
# Processing Record 20 of Set 28 | shchelyayur
# City not found. Skipping...
# Processing Record 21 of Set 28 | sola
# Processing Record 22 of Set 28 | bogatoye
# Processing Record 23 of Set 28 | takoradi
# Processing Record 24 of Set 28 | jumla
# Processing Record 25 of Set 28 | manama
# Processing Record 26 of Set 28 | ponta delgada
# Processing Record 27 of Set 28 | gurupa
# Processing Record 28 of Set 28 | tsumeb
# Processing Record 29 of Set 28 | bere
# Processing Record 30 of Set 28 | whitehorse
# Processing Record 31 of Set 28 | lagos
# Processing Record 32 of Set 28 | ilek
# Processing Record 33 of Set 28 | wulanhaote
# City not found. Skipping...
# Processing Record 34 of Set 28 | la ronge
# Processing Record 35 of Set 28 | klyuchi
# Processing Record 36 of Set 28 | karpathos
# Processing Record 37 of Set 28 | taoudenni
# Processing Record 38 of Set 28 | ruwi
# Processing Record 39 of Set 28 | nalut
# Processing Record 40 of Set 28 | mountain home
# Processing Record 41 of Set 28 | kautokeino
# Processing Record 42 of Set 28 | san quintin
# Processing Record 43 of Set 28 | ryotsu
# Processing Record 44 of Set 28 | parkersburg
# Processing Record 45 of Set 28 | eydhafushi
# Processing Record 46 of Set 28 | tabatinga
# Processing Record 47 of Set 28 | surt
# Processing Record 48 of Set 28 | morant bay
# Processing Record 49 of Set 28 | miles city
# Processing Record 50 of Set 28 | dauphin
# Processing Record 1 of Set 29 | bilma
# Processing Record 2 of Set 29 | hambantota
# Processing Record 3 of Set 29 | turukhansk
# Processing Record 4 of Set 29 | la paz
# Processing Record 5 of Set 29 | baiyin
# Processing Record 6 of Set 29 | alice
# Processing Record 7 of Set 29 | san francisco menendez
# Processing Record 8 of Set 29 | mikhaylovka
# Processing Record 9 of Set 29 | nauta
# Processing Record 10 of Set 29 | zalantun
# Processing Record 11 of Set 29 | ulaangom
# Processing Record 12 of Set 29 | kinablangan
# Processing Record 13 of Set 29 | bubaque
# Processing Record 14 of Set 29 | hervey bay
# Processing Record 15 of Set 29 | alberdi
# Processing Record 16 of Set 29 | sibu
# Processing Record 17 of Set 29 | birao
# Processing Record 18 of Set 29 | troyes
# Processing Record 19 of Set 29 | shache
# Processing Record 20 of Set 29 | wanning
# Processing Record 21 of Set 29 | pryozerne
# Processing Record 22 of Set 29 | paradwip
# City not found. Skipping...
# Processing Record 23 of Set 29 | vetluzhskiy
# Processing Record 24 of Set 29 | krutaya gorka
# Processing Record 25 of Set 29 | kovdor
# Processing Record 26 of Set 29 | alice springs
# Processing Record 27 of Set 29 | katobu
# Processing Record 28 of Set 29 | gazojak
# Processing Record 29 of Set 29 | bhag
# Processing Record 30 of Set 29 | nueva gerona
# Processing Record 31 of Set 29 | severomuysk
# Processing Record 32 of Set 29 | oprisor
# Processing Record 33 of Set 29 | atar
# Processing Record 34 of Set 29 | bonthe
# Processing Record 35 of Set 29 | zelenoborsk
# Processing Record 36 of Set 29 | de-kastri
# Processing Record 37 of Set 29 | sosnovka
# Processing Record 38 of Set 29 | salmas
# Processing Record 39 of Set 29 | jalu
# Processing Record 40 of Set 29 | itaituba
# Processing Record 41 of Set 29 | guadalajara
# Processing Record 42 of Set 29 | parsabad
# Processing Record 43 of Set 29 | brigg
# Processing Record 44 of Set 29 | los alamos
# Processing Record 45 of Set 29 | parati
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(5)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Port Blair  11.6667   92.7500     75.20        83          20        4.81
# 1    Kamiichi  36.7000  137.3667     46.99        60          40        3.44
# 2       Pisco -13.7000  -76.2167     73.40        83           0       17.27
# 3     Rikitea -23.1203 -134.9692     79.99        80          77       13.58
# 4        Asau  46.4333   26.4000     24.01        65           1        4.72
#
#   Country   Current Weather
# 0      IN              mist
# 1      JP  scattered clouds
# 2      PE         clear sky
# 3      PF     broken clouds
# 4      RO         clear sky

# %%
print(city_weather)
# Out:
# {'coord': {'lon': -44.7131, 'lat': -23.2178}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 74.61, 'feels_like': 80.37, 'temp_min': 74.61, 'temp_max': 74.61, 'pressure': 1012, 'humidity': 86, 'sea_level': 1012, 'grnd_level': 1012}, 'visibility': 805, 'wind': {'speed': 3.44, 'deg': 176}, 'rain': {'1h': 2.05}, 'clouds': {'all': 100}, 'dt': 1615083023, 'sys': {'country': 'BR', 'sunrise': 1615021023, 'sunset': 1615065803}, 'timezone': -10800, 'id': 3455036, 'name': 'Paraty', 'cod': 200}

# %%
#reorder the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Weather"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Port Blair      IN  11.6667   92.7500     75.20        83          20
# 1       Kamiichi      JP  36.7000  137.3667     46.99        60          40
# 2          Pisco      PE -13.7000  -76.2167     73.40        83           0
# 3        Rikitea      PF -23.1203 -134.9692     79.99        80          77
# 4           Asau      RO  46.4333   26.4000     24.01        65           1
# ..           ...     ...      ...       ...       ...       ...         ...
# 686  Guadalajara      MX  20.6667 -103.3333     77.00        15          20
# 687     Parsabad      IR  39.6482   47.9174     41.00        75           0
# 688        Brigg      GB  53.5520   -0.4921     35.01        80          90
# 689   Los Alamos      US  35.8881 -106.3070     46.40        23           1
# 690       Parati      BR -23.2178  -44.7131     74.61        86         100
#
#      Wind Speed   Current Weather
# 0          4.81              mist
# 1          3.44  scattered clouds
# 2         17.27         clear sky
# 3         13.58     broken clouds
# 4          4.72         clear sky
# ..          ...               ...
# 686        4.61        few clouds
# 687       11.50         clear sky
# 688        4.61   overcast clouds
# 689        9.22         clear sky
# 690        3.44     moderate rain
#
# [691 rows x 9 columns]

# %%
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': -44.7131, 'lat': -23.2178},
#  'weather': [{'id': 501,
#    'main': 'Rain',
#    'description': 'moderate rain',
#    'icon': '10n'}],
#  'base': 'stations',
#  'main': {'temp': 74.61,
#   'feels_like': 80.37,
#   'temp_min': 74.61,
#   'temp_max': 74.61,
#   'pressure': 1012,
#   'humidity': 86,
#   'sea_level': 1012,
#   'grnd_level': 1012},
#  'visibility': 805,
#  'wind': {'speed': 3.44, 'deg': 176},
#  'rain': {'1h': 2.05},
#  'clouds': {'all': 100},
#  'dt': 1615083023,
#  'sys': {'country': 'BR', 'sunrise': 1615021023, 'sunset': 1615065803},
#  'timezone': -10800,
#  'id': 3455036,
#  'name': 'Paraty',
#  'cod': 200}

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

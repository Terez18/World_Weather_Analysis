# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID        City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0  Port Blair      IN  11.6667   92.7500     75.20        83
# 1        1    Kamiichi      JP  36.7000  137.3667     46.99        60
# 2        2       Pisco      PE -13.7000  -76.2167     73.40        83
# 3        3     Rikitea      PF -23.1203 -134.9692     79.99        80
# 4        4        Asau      RO  46.4333   26.4000     24.01        65
#
#    Cloudiness  Wind Speed   Current Weather
# 0          20        4.81              mist
# 1          40        3.44  scattered clouds
# 2           0       17.27         clear sky
# 3          77       13.58     broken clouds
# 4           1        4.72         clear sky

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 70
# What is the maximum temperature you would like for your trip? 85

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID            City Country      Lat       Lng  Max Temp  Humidity  \
# 0         0      Port Blair      IN  11.6667   92.7500     75.20        83
# 2         2           Pisco      PE -13.7000  -76.2167     73.40        83
# 3         3         Rikitea      PF -23.1203 -134.9692     79.99        80
# 5         5         Sechura      PE  -5.5569  -80.8222     78.94        64
# 17       17  Saint-Philippe      RE -21.3585   55.7679     80.60        83
# 19       19          Banjar      ID  -8.1900  114.9675     84.20        79
# 21       21       Busselton      AU -33.6500  115.3333     71.01        78
# 28       28       Mahebourg      MU -20.4081   57.7000     80.60        83
# 34       34    Puerto Ayora      EC  -0.7393  -90.3518     77.00        95
# 36       36         Kahului      US  20.8947 -156.4700     80.60        44
#
#     Cloudiness  Wind Speed   Current Weather
# 0           20        4.81              mist
# 2            0       17.27         clear sky
# 3           77       13.58     broken clouds
# 5            4       12.24         clear sky
# 17          75       13.80        light rain
# 19          20        3.44        few clouds
# 21           0        1.01         clear sky
# 28          75       17.27        light rain
# 34          58        6.55        light rain
# 36          40       23.02  scattered clouds

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.isnull().sum()
# Out:
# City_ID            0
# City               0
# Country            0
# Lat                0
# Lng                0
# Max Temp           0
# Humidity           0
# Cloudiness         0
# Wind Speed         0
# Current Weather    0
# dtype: int64

# %%
preferred_cities_df.count()
# Out:
# City_ID            237
# City               237
# Country            237
# Lat                237
# Lng                237
# Max Temp           237
# Humidity           237
# Cloudiness         237
# Wind Speed         237
# Current Weather    237
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
preferred_cities_df_clean = preferred_cities_df.dropna()
preferred_cities_df_clean
# Out:
#      City_ID            City Country      Lat       Lng  Max Temp  Humidity  \
# 0          0      Port Blair      IN  11.6667   92.7500     75.20        83
# 2          2           Pisco      PE -13.7000  -76.2167     73.40        83
# 3          3         Rikitea      PF -23.1203 -134.9692     79.99        80
# 5          5         Sechura      PE  -5.5569  -80.8222     78.94        64
# 17        17  Saint-Philippe      RE -21.3585   55.7679     80.60        83
# ..       ...             ...     ...      ...       ...       ...       ...
# 675      675    Nueva Gerona      CU  21.8833  -82.8000     76.05        74
# 679      679          Bonthe      SL   7.5264  -12.5050     77.79        90
# 685      685        Itaituba      BR  -4.2761  -55.9836     75.20       100
# 686      686     Guadalajara      MX  20.6667 -103.3333     77.00        15
# 690      690          Parati      BR -23.2178  -44.7131     74.61        86
#
#      Cloudiness  Wind Speed       Current Weather
# 0            20        4.81                  mist
# 2             0       17.27             clear sky
# 3            77       13.58         broken clouds
# 5             4       12.24             clear sky
# 17           75       13.80            light rain
# ..          ...         ...                   ...
# 675          28       10.16      scattered clouds
# 679         100        4.76       overcast clouds
# 685          90        5.75  heavy intensity rain
# 686          20        4.61            few clouds
# 690         100        3.44         moderate rain
#
# [237 rows x 10 columns]

# %%
preferred_cities_df_clean.count()
# Out:
# City_ID            237
# City               237
# Country            237
# Lat                237
# Lng                237
# Max Temp           237
# Humidity           237
# Cloudiness         237
# Wind Speed         237
# Current Weather    237
# dtype: int64

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df_clean[["City", "Country", "Max Temp", "Current Weather", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#               City Country  Max Temp   Current Weather      Lat       Lng  \
# 0       Port Blair      IN     75.20              mist  11.6667   92.7500
# 2            Pisco      PE     73.40         clear sky -13.7000  -76.2167
# 3          Rikitea      PF     79.99     broken clouds -23.1203 -134.9692
# 5          Sechura      PE     78.94         clear sky  -5.5569  -80.8222
# 17  Saint-Philippe      RE     80.60        light rain -21.3585   55.7679
# 19          Banjar      ID     84.20        few clouds  -8.1900  114.9675
# 21       Busselton      AU     71.01         clear sky -33.6500  115.3333
# 28       Mahebourg      MU     80.60        light rain -20.4081   57.7000
# 34    Puerto Ayora      EC     77.00        light rain  -0.7393  -90.3518
# 36         Kahului      US     80.60  scattered clouds  20.8947 -156.4700
#
#    Hotel Name
# 0
# 2
# 3
# 5
# 17
# 19
# 21
# 28
# 34
# 36

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
lat = hotel_df.iloc[0]['Lat']
lng =  hotel_df.iloc[0]['Lng']

# %%
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}
params["location"] = f"{lat},{lng}"
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
hotel_name = requests.get(base_url, params=params).json()  
hotel_name
# Out:
# {'html_attributions': [],
#  'next_page_token': 'ATtYBwJfabmzVlyE5foETnamgwMtIK1BtghZdygisuROVe3MbXYKqxhONoi7FyAG7mGvbW0EQMjT3QRQFB-kBJMtg3OxZFqavovF8jP9jqSDWyZ91pPAy-9Ib0uxiZzVzWSrKNkR1GARKF2uw0AAaawT5YxYHf1eTgXcezgAx8esoQ-433mr_zsUIktBCSnM-8YrFrQULiv96OZ982xJlqgb3CkhybwcmfgGOKFmrQVwDBAH2d-kMzPNKuzfBvePdzaYbFjMFqTxjq3XmRv2Imcf0ifaEZebx0iodevlmDyyi0zOOI3lzLlw43qTySabLtDmoOLJxLYYriuuzM4jq5fnkFiiCoqYyCopX-K7cHitZz9wJwK5wrAAI8clGrPGiWNqbB9doxEMx1ZpIG-ImZtdlVKcpHm8SAoxqgZ3fxb1VDW5gZZQ4eQ8jG1Y',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.6761772, 'lng': 92.74020039999999},
#     'viewport': {'northeast': {'lat': 11.6773412302915,
#       'lng': 92.74168563029149},
#      'southwest': {'lat': 11.6746432697085, 'lng': 92.73898766970848}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Welcomhotel Bay Island Port Blair',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1954,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117868258779402998319">Welcomhotel Bay Island Port Blair</a>'],
#      'photo_reference': 'ATtYBwIwc_kvLPb586cmyQULjLRNJMim1jSSbtcCiyoi0evzEwJLkNojFGD8faEWl1irA2xbFAEQGWWftM0ooK8sDODqrq7kJtQikmgcpTsvrTvouRTYtvTdVfkKatpD-SOWU87QwRmhGSa7vUs6P9n1ngLzPnwJ3oYi0iY6lRRjecjUx9fh',
#      'width': 2829}],
#    'place_id': 'ChIJh_mDIBWViDARFwf2YL6xKRQ',
#    'plus_code': {'compound_code': 'MPGR+F3 Port Blair, Andaman and Nicobar Islands, India',
#     'global_code': '7M3JMPGR+F3'},
#    'rating': 4.2,
#    'reference': 'ChIJh_mDIBWViDARFwf2YL6xKRQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 828,
#    'vicinity': 'Marine Hill, Port Blair'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.6648526, 'lng': 92.73538649999999},
#     'viewport': {'northeast': {'lat': 11.6663916302915,
#       'lng': 92.73664273029149},
#      'southwest': {'lat': 11.6636936697085, 'lng': 92.73394476970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hotel Sentinel',
#    'photos': [{'height': 682,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106965314069277915416">Hotel Sentinel</a>'],
#      'photo_reference': 'ATtYBwK0hJjr_vC0MqQx9xkGRhjQC7GKDcV4RYtYRN98pUXrQetuRWAj8GmHyngVJOkiKHCuf8vKgRDsh-iuUAC1MOxEKiys-22FBx-8TNoZKNEbGJ9cWkKHVLiVXl3riSaswISzfqZi4WqKLu47DNEU4HL3W1qxs-nCya3_I1Jqy-yl5cxA',
#      'width': 1024}],
#    'place_id': 'ChIJ____76GViDARudvrFYzNqbQ',
#    'plus_code': {'compound_code': 'MP7P+W5 Port Blair, Andaman and Nicobar Islands, India',
#     'global_code': '7M3JMP7P+W5'},
#    'rating': 3.8,
#    'reference': 'ChIJ____76GViDARudvrFYzNqbQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 445,
#    'vicinity': 'Phoenix Bay, Port Blair'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.6691667, 'lng': 92.74249999999999},
#     'viewport': {'northeast': {'lat': 11.6705034302915,
#       'lng': 92.7439047302915},
#      'southwest': {'lat': 11.6678054697085, 'lng': 92.7412067697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'J Hotel',
#    'photos': [{'height': 3120,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109203149821389498050">Sanjay Bhasin</a>'],
#      'photo_reference': 'ATtYBwJzAGnyo_2CwnCy6Qr7Q1jblpM4QB3S1ywNypUesgJhYvmQ9CfXDTg6k3c1VQiSgQTGVC_F0Z3Y6Rc2h89veY7w6GigInEcIA5ryMcZNhbE864Fsq5xw56Jl_r4SZo2gTDhAp85TC7-S6_KmgwkgUEaoLCHVVhc-ZbXunP_yEl1leXi',
#      'width': 4160}],
#    'place_id': 'ChIJoYcvPQuViDARG22o_0beoZY',
#    'plus_code': {'compound_code': 'MP9V+M2 Port Blair, Andaman and Nicobar Islands, India',
#     'global_code': '7M3JMP9V+M2'},
#    'rating': 3.7,
#    'reference': 'ChIJoYcvPQuViDARG22o_0beoZY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 959,
#    'vicinity': 'Aberdeen Bazaar, Near Clock Tower, Port Blair'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.672305, 'lng': 92.74239},
#     'viewport': {'northeast': {'lat': 11.6736436802915,
#       'lng': 92.7437075802915},
#      'southwest': {'lat': 11.6709457197085, 'lng': 92.74100961970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hotel Lalaji Bayview',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 424,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105042544581762817333">Hotel Lalaji Bayview</a>'],
#      'photo_reference': 'ATtYBwKKAtuVJ0DFTZ96bfMGsJE8xrMGoa4zhlnSZ9WuA5mS7nqtmuvughICmWOhMygjz3J2JHWWLYQ1SGNVznDPt9x50ePTY4e48W9tLE_NPNDkaq0rrXGujBLTYwnY3b9CDw81MH5JYpQKDMkU-JqDbCO86ubQTBEcsNSqrPAwmafasgTq',
#      'width': 624}],
#    'place_id': 'ChIJffzzvHSViDARHfGHJ25jqig',
#    'plus_code': {'compound_code': 'MPCR+WX Port Blair, Andaman and Nicobar Islands, India',
#     'global_code': '7M3JMPCR+WX'},
#    'rating': 3.8,
#    'reference': 'ChIJffzzvHSViDARHfGHJ25jqig',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 215,
#    'vicinity': 'R P Road, Dignabad, Port Blair'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.675764, 'lng': 92.73972660000001},
#     'viewport': {'northeast': {'lat': 11.6770531802915,
#       'lng': 92.74104583029153},
#      'southwest': {'lat': 11.6743552197085, 'lng': 92.73834786970852}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Sea Shell, Port Blair',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2760,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112640210897222207243">Sea Shell, Port Blair</a>'],
#      'photo_reference': 'ATtYBwIr6aBxOqCAKaX0HN9fzZx43tCWmrO7yh-lgQdv3_ajONF3GtG0E_c_a2Nn8ZEzhSKPEjQa0pyy5f8Tt07ulFHEQyoDftV9jD3C-W2NkdMdXeqZ2xyv0RK0F_JdwU2WVmBkjZyWNqZTIpXYwz9dTGed_nhiXEirwJA-ERPS-bhmvuSd',
#      'width': 4896}],
#    'place_id': 'ChIJRUy3L6KViDARK-IkN7dCJhc',
#    'plus_code': {'compound_code': 'MPGQ+8V Port Blair, Andaman and Nicobar Islands, India',
#     'global_code': '7M3JMPGQ+8V'},
#    'rating': 4.3,
#    'reference': 'ChIJRUy3L6KViDARK-IkN7dCJhc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 911,
#    'vicinity': 'Marine Hill, Port Blair'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.6826307, 'lng': 92.723773},
#     'viewport': {'northeast': {'lat': 11.6839896802915,
#       'lng': 92.72516828029151},
#      'southwest': {'lat': 11.6812917197085, 'lng': 92.72247031970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Kokari Guesthouse',
#    'place_id': 'ChIJEagVBaCViDARB5S84XrnFD8',
#    'plus_code': {'compound_code': 'MPMF+3G Port Blair, Andaman and Nicobar Islands, India',
#     'global_code': '7M3JMPMF+3G'},
#    'rating': 2,
#    'reference': 'ChIJEagVBaCViDARB5S84XrnFD8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': '03, Foreshore Road, Haddo, Port Blair'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.6638864, 'lng': 92.75567649999999},
#     'viewport': {'northeast': {'lat': 11.6652331802915,
#       'lng': 92.75689503029149},
#      'southwest': {'lat': 11.6625352197085, 'lng': 92.75419706970848}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Sinclairs Bayview Port Blair',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102243026616141016928">Sinclairs Bayview Port Blair</a>'],
#      'photo_reference': 'ATtYBwLnAUYBZ4XR1xdCHf7A-idEdOnerQmAOkOy0TFcdbDUuG05jg31r6dWKlXfcAsa7jE3T1gSUamBPF_mNQOeKUOXrMdydkY58clRQHR2ChjcfL-63Er_6F-46t5tRbpPbZUluiLonMQ-ZPgbGwVfhJI44ParNrZLEh9q1hgroZLcgd6O',
#      'width': 2048}],
#    'place_id': 'ChIJtVncXxaViDARhH1hzeEET-c',
#    'plus_code': {'compound_code': 'MQ74+H7 Port Blair, Andaman and Nicobar Islands, India',
#     'global_code': '7M3JMQ74+H7'},
#    'rating': 4.2,
#    'reference': 'ChIJtVncXxaViDARhH1hzeEET-c',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 904,
#    'vicinity': 'Corbyns Cove Road, South Point, Shadipur, Port Blair'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.6703728, 'lng': 92.72746520000001},
#     'viewport': {'northeast': {'lat': 11.6717532302915,
#       'lng': 92.72881258029153},
#      'southwest': {'lat': 11.6690552697085, 'lng': 92.72611461970853}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hotel TEJAS',
#    'place_id': 'ChIJSyMZRb2ViDAR1qNUQUZ-hSA',
#    'rating': 4.7,
#    'reference': 'ChIJSyMZRb2ViDAR1qNUQUZ-hSA',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': '29, Jawaharlal Nehru Road, Haddo, Port Blair'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.6703135, 'lng': 92.74050539999999},
#     'viewport': {'northeast': {'lat': 11.6716546302915,
#       'lng': 92.7418531802915},
#      'southwest': {'lat': 11.6689566697085, 'lng': 92.7391552197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Katchal Inn',
#    'photos': [{'height': 774,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104636044804339352069">Katchal Inn</a>'],
#      'photo_reference': 'ATtYBwLAUhtqABrydS24T5LiF_7_zw8WrMYZKI0iinKnWpUNQeElzHBGyVEv4z_ojCBw3gc3B0lI6qbL4z0SBbTNWbrjW1qMAZET6o9lQkTEZVvXgPas38pgS6BTkFB9_H8RcnilcE892uQYNLW1Wk1UtvxV8rKOOA92UAdIJzhei1aHDu7p',
#      'width': 1032}],
#    'place_id': 'ChIJAQAALwuViDARQnV7eXwAqEA',
#    'plus_code': {'compound_code': 'MPCR+46 Port Blair, Andaman and Nicobar Islands, India',
#     'global_code': '7M3JMPCR+46'},
#    'rating': 3.5,
#    'reference': 'ChIJAQAALwuViDARQnV7eXwAqEA',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'Katchal Inn, Babu Lane, Aberdeen Bazar, Mohanpura, Port Blair'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.6705797, 'lng': 92.7295242},
#     'viewport': {'northeast': {'lat': 11.6719269302915,
#       'lng': 92.73088688029151},
#      'southwest': {'lat': 11.6692289697085, 'lng': 92.7281889197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'OYO 44650 Palika Palace',
#    'place_id': 'ChIJ_dtomKKViDARjWKrYSGDO5k',
#    'plus_code': {'compound_code': 'MPCH+6R Port Blair, Andaman and Nicobar Islands, India',
#     'global_code': '7M3JMPCH+6R'},
#    'reference': 'ChIJ_dtomKKViDARjWKrYSGDO5k',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '99, Jawaharlal Nehru Road, Delanipur, Port Blair'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.6688966, 'lng': 92.7262988},
#     'viewport': {'northeast': {'lat': 11.6702054802915,
#       'lng': 92.7276950302915},
#      'southwest': {'lat': 11.6675075197085, 'lng': 92.7249970697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'OYO 18768 Hotel Aqua Breeze',
#    'place_id': 'ChIJRSQnBb2ViDARCr9i9YCa86I',
#    'plus_code': {'compound_code': 'MP9G+HG Port Blair, Andaman and Nicobar Islands, India',
#     'global_code': '7M3JMP9G+HG'},
#    'rating': 5,
#    'reference': 'ChIJRSQnBb2ViDARCr9i9YCa86I',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': '000, Buniadabad, near Ayappa Temple, Delanipur, Port Blair, Andaman and Nicobar Islands 744102, Port Blair'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.662268, 'lng': 92.734927},
#     'viewport': {'northeast': {'lat': 11.6637486302915,
#       'lng': 92.73629048029152},
#      'southwest': {'lat': 11.6610506697085, 'lng': 92.7335925197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Vista Rooms at Goalghar',
#    'place_id': 'ChIJs5KEWaaViDAR46hvg0YKAdI',
#    'plus_code': {'compound_code': 'MP6M+WX Port Blair, Andaman and Nicobar Islands, India',
#     'global_code': '7M3JMP6M+WX'},
#    'rating': 3,
#    'reference': 'ChIJs5KEWaaViDAR46hvg0YKAdI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Shreesh Hotel, Link Road, Goal Ghar, Junglighat, Port Blair'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.6507922, 'lng': 92.74377659999999},
#     'viewport': {'northeast': {'lat': 11.6518776302915,
#       'lng': 92.74528138029149},
#      'southwest': {'lat': 11.6491796697085, 'lng': 92.74258341970848}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'OYO 9589 Hotel Aries',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 427,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103527442336826362558">OYO 9589 Hotel Aries</a>'],
#      'photo_reference': 'ATtYBwIVz-3iCVFfbrZ5DAMEb6TeRdhvJusoTKHATY_r5RsATwqREtC6DrQYzrkEkAwymkQRxAYjQJHqJtGu7JAgyBRmRzzcYWev-500Qi0IqGOJ80wwvCXd2Sh-z7wWscYR9uoHxnXldGTkoOQKCIKf_dQivj1lA2BXtGfQ8qeAKM4BBaJC',
#      'width': 640}],
#    'place_id': 'ChIJ7xABMgKViDARXuXktBPNZBs',
#    'plus_code': {'compound_code': 'MP2V+8G Port Blair, Andaman and Nicobar Islands, India',
#     'global_code': '7M3JMP2V+8G'},
#    'rating': 3.5,
#    'reference': 'ChIJ7xABMgKViDARXuXktBPNZBs',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 121,
#    'vicinity': 'DudhLine,, Dudhline Nayagaon,, Port Blair'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.644183, 'lng': 92.74609600000001},
#     'viewport': {'northeast': {'lat': 11.6459005802915,
#       'lng': 92.74732563029153},
#      'southwest': {'lat': 11.6432026197085, 'lng': 92.74462766970852}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Peerless Resort Port Blair',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109731352870861263544">Francois G</a>'],
#      'photo_reference': 'ATtYBwKaOdUrq0-voQAbBSUTHlwIX54OUmrdGpyoM5NKKHbpcRrDUu-j-QWdxHW3JKmM1fxswf6WQgdI5eAV-3qWlHriVqAcyssCyVJDDCiUB0Gao-QOxPX9-D49fACOKGdjtNS0KYzv6AOcOkGIPcIHlmgB58T5q31_ZFGB5Kj_sdPkuXsL',
#      'width': 4032}],
#    'place_id': 'ChIJoydAjfyUiDARFPUjmMpn8vQ',
#    'plus_code': {'compound_code': 'JPVW+MC Port Blair, Andaman and Nicobar Islands, India',
#     'global_code': '7M3JJPVW+MC'},
#    'rating': 3.8,
#    'reference': 'ChIJoydAjfyUiDARFPUjmMpn8vQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 732,
#    'vicinity': 'Corbyns Cove Road, Port Blair'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.668761, 'lng': 92.7315208},
#     'viewport': {'northeast': {'lat': 11.6701405302915,
#       'lng': 92.7328683302915},
#      'southwest': {'lat': 11.6674425697085, 'lng': 92.73017036970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'TSG Emerald View',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2128,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106788751704713605179">Amulya R</a>'],
#      'photo_reference': 'ATtYBwJQ20_f1xMOjfe1yGzn7fMfbbjhj8XB-YX1Vt7OTHqcSV8OZxJ-_opuiByVuo_dT6-Q-ow2y1b5ssRfOP5-We_vP-If01PyHQjR8b5JwhR21jo5wKG329exYs_Pjo7mvUrscwqMK-ypGMBG4idsnq0B4iTdlRI_3ZKftRfV7L65VtCO',
#      'width': 4608}],
#    'place_id': 'ChIJGTY6LT-ViDARZq_egC9aDGI',
#    'plus_code': {'compound_code': 'MP9J+GJ Port Blair, Andaman and Nicobar Islands, India',
#     'global_code': '7M3JMP9J+GJ'},
#    'rating': 4,
#    'reference': 'ChIJGTY6LT-ViDARZq_egC9aDGI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 838,
#    'vicinity': '26/1, MA Road, Phoenix Bay, Port Blair'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.6821267, 'lng': 92.7238478},
#     'viewport': {'northeast': {'lat': 11.6835036302915,
#       'lng': 92.7252622802915},
#      'southwest': {'lat': 11.6808056697085, 'lng': 92.72256431970848}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Da Bay Inn',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2304,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116424440855863897847">Ajay Kumar</a>'],
#      'photo_reference': 'ATtYBwJbxGCVM3rVE_86mxzLqj6iIbFOydlNJmw611y1xRLcfq3zITKKvaYu7YduoBILJGJ53nHa_ciCcJVrtEq_DbNdYOLN5gf1zH3oonScvMluBra7288qRkvvUjSNUYWc-isK055bzTqDB0Um67Yz-DA0f-J8sJLPzJuCxTKgNzDFBCEV',
#      'width': 4096}],
#    'place_id': 'ChIJldIz-5GViDARqymq60v0DDw',
#    'plus_code': {'compound_code': 'MPJF+VG Port Blair, Andaman and Nicobar Islands, India',
#     'global_code': '7M3JMPJF+VG'},
#    'rating': 3.5,
#    'reference': 'ChIJldIz-5GViDARqymq60v0DDw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 300,
#    'vicinity': 'Sea Shore Road, Haddo, Port Blair, Port Blair'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.6652584, 'lng': 92.7314574},
#     'viewport': {'northeast': {'lat': 11.6665870302915,
#       'lng': 92.73286643029151},
#      'southwest': {'lat': 11.6638890697085, 'lng': 92.7301684697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Andaman Residency',
#    'photos': [{'height': 2304,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111566496882477865458">Akash Negi</a>'],
#      'photo_reference': 'ATtYBwKY3YyZdtiZuzpyRSkbOuXAtPMS11nO8AqiufeL9CPNjU7knm7dLBT3ue2wWHKRNt4aI_v1tnIdb6NNy495_X3M-vp1b50EPCc_vCjwIhyiVn7tGdLKkAG7c4DdtDFtW_i3SwnUEYzv7DFLXbyfxAn92sx6lwz8ZkR6JFqqrVOavh7v',
#      'width': 4608}],
#    'place_id': 'ChIJVXWXfqCViDARMQBVxm0wssQ',
#    'plus_code': {'compound_code': 'MP8J+4H Port Blair, Andaman and Nicobar Islands, India',
#     'global_code': '7M3JMP8J+4H'},
#    'rating': 3.4,
#    'reference': 'ChIJVXWXfqCViDARMQBVxm0wssQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 291,
#    'vicinity': 'India'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.6694186, 'lng': 92.7282827},
#     'viewport': {'northeast': {'lat': 11.6708302302915,
#       'lng': 92.72963998029151},
#      'southwest': {'lat': 11.6681322697085, 'lng': 92.7269420197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hotel Dev Haweli',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1158,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117005193311191461297">Hotel Dev Haweli</a>'],
#      'photo_reference': 'ATtYBwKDBKZ0jQIVIepjP8QJ8u_MEt1LJp9uiIsPZLXi3NhPpJl7_RJWXhKQEDMRUm85qwlHyRT7hrUC8Cuk3j1oV2403_V9-vxUBwhk19MtMA12P0YllcqCtWC3jdcHK-TA1BZahN0rMcEdoz6TS_vYlZH6LH2uP3prqC1ESTNaELVlUCdx',
#      'width': 2048}],
#    'place_id': 'ChIJXeV_0KKViDARo9NBaAMUb_g',
#    'plus_code': {'compound_code': 'MP9H+Q8 Port Blair, Andaman and Nicobar Islands, India',
#     'global_code': '7M3JMP9H+Q8'},
#    'rating': 3.8,
#    'reference': 'ChIJXeV_0KKViDARo9NBaAMUb_g',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 260,
#    'vicinity': '105/6, Anarkali,, Delanipur,, Port Blair'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.6784544, 'lng': 92.72930690000001},
#     'viewport': {'northeast': {'lat': 11.6793792302915,
#       'lng': 92.73050573029151},
#      'southwest': {'lat': 11.6766812697085, 'lng': 92.72780776970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'OYO 10180 Hotel Value',
#    'photos': [{'height': 3000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113002889668054615865">ramesh kannusamy</a>'],
#      'photo_reference': 'ATtYBwIb0_xeWpZfEmMNU4xLH9ZJ_Prq7cuA_-38CzSGpfmyzQzDh-fwM5qMn3ueWewX_j37q7bpSCh-5r8wH-vPaHXenqfFeyNeLBtVcYrX0zP-FdFvrrBkpDMaf0h6UZTS-dsuKBgUqgbi5OqAcMw2VajA3f2OedWhTSnGdcLQYBVX7BSA',
#      'width': 4000}],
#    'place_id': 'ChIJAQAAa5qViDARjp6n1tyUrZI',
#    'rating': 3.7,
#    'reference': 'ChIJAQAAa5qViDARjp6n1tyUrZI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 22,
#    'vicinity': 'Dollygunj, Port-Blair, Port Blair'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.649126, 'lng': 92.731679},
#     'viewport': {'northeast': {'lat': 11.6505432802915,
#       'lng': 92.7330248302915},
#      'southwest': {'lat': 11.6478453197085, 'lng': 92.73032686970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Diviyum Manor',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2592,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104114339091332777242">J V</a>'],
#      'photo_reference': 'ATtYBwKFeZLKIPwE643OL_HcF9LiaDUAwXuvAnDh4TE-Hb7DwhbCJV52oNgtgkd4QFcHlpvYtVMftKTNEusvlvoRBuJYn218e5TGJfKL2t2cQ43DSa1wtQpuC6Pe6Hrj9AZUqTZflNBlVkLL2Ex3Wf5MrYw7C-4Iva0zi_IIVoaa8zrGI0iX',
#      'width': 4608}],
#    'place_id': 'ChIJtykdxqyViDAR6T0Og_QY-ns',
#    'plus_code': {'compound_code': 'JPXJ+MM Port Blair, Andaman and Nicobar Islands, India',
#     'global_code': '7M3JJPXJ+MM'},
#    'rating': 3.8,
#    'reference': 'ChIJtykdxqyViDAR6T0Og_QY-ns',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 332,
#    'vicinity': 'Opposite to Veer Savarkar Airport, Lamba Line, Port Blair'}],
#  'status': 'OK'}

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():

    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    params["location"] = f"{lat},{lng}"
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotel_name = requests.get(base_url, params=params).json()                             

    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.

    try:
        hotel_df.loc[index, "Hotel Name"] = hotel_name["results"][2]["name"]

    except(KeyError, IndexError):
        print("error")

hotel_df
# Out:
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
#                City Country  Max Temp       Current Weather      Lat  \
# 0        Port Blair      IN     75.20                  mist  11.6667
# 2             Pisco      PE     73.40             clear sky -13.7000
# 3           Rikitea      PF     79.99         broken clouds -23.1203
# 5           Sechura      PE     78.94             clear sky  -5.5569
# 17   Saint-Philippe      RE     80.60            light rain -21.3585
# ..              ...     ...       ...                   ...      ...
# 675    Nueva Gerona      CU     76.05      scattered clouds  21.8833
# 679          Bonthe      SL     77.79       overcast clouds   7.5264
# 685        Itaituba      BR     75.20  heavy intensity rain  -4.2761
# 686     Guadalajara      MX     77.00            few clouds  20.6667
# 690          Parati      BR     74.61         moderate rain -23.2178
#
#           Lng                Hotel Name
# 0     92.7500                   J Hotel
# 2    -76.2167     Hostal Tambo Colorado
# 3   -134.9692
# 5    -80.8222  Hotel Amanecer - Sechura
# 17    55.7679            Pinpin d'Amour
# ..        ...                       ...
# 675  -82.8000              Villa Ninita
# 679  -12.5050
# 685  -55.9836             Hotel Avenida
# 686 -103.3333             Hotel Francés
# 690  -44.7131           Pousada Talisma
#
# [237 rows x 7 columns]

# %%
# 7. Drop the rows where there is no Hotel Name.

hotel_df_clean = hotel_df[hotel_df["Hotel Name"]!= ""]

hotel_df_clean
# Out:
#                City Country  Max Temp       Current Weather      Lat  \
# 0        Port Blair      IN     75.20                  mist  11.6667
# 2             Pisco      PE     73.40             clear sky -13.7000
# 5           Sechura      PE     78.94             clear sky  -5.5569
# 17   Saint-Philippe      RE     80.60            light rain -21.3585
# 19           Banjar      ID     84.20            few clouds  -8.1900
# ..              ...     ...       ...                   ...      ...
# 666         Wanning      CN     78.51      scattered clouds  18.8003
# 675    Nueva Gerona      CU     76.05      scattered clouds  21.8833
# 685        Itaituba      BR     75.20  heavy intensity rain  -4.2761
# 686     Guadalajara      MX     77.00            few clouds  20.6667
# 690          Parati      BR     74.61         moderate rain -23.2178
#
#           Lng                            Hotel Name
# 0     92.7500                               J Hotel
# 2    -76.2167                 Hostal Tambo Colorado
# 5    -80.8222              Hotel Amanecer - Sechura
# 17    55.7679                        Pinpin d'Amour
# 19   114.9675  The Raja Singha Boutique Resort Bali
# ..        ...                                   ...
# 666  110.3967                        Wangshui Hotel
# 675  -82.8000                          Villa Ninita
# 685  -55.9836                         Hotel Avenida
# 686 -103.3333                         Hotel Francés
# 690  -44.7131                       Pousada Talisma
#
# [194 rows x 7 columns]

# %%
# 8a. Create the output File (CSV)
output_data_file = "WeatherPy_vacation.csv"

# 8b. Export the City_Data into a csv
hotel_df_clean.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Weather}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df_clean.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = hotel_df_clean[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
max_temp = hotel_df_clean["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
# 11b. Display the figure

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
